# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="k0J1VMB7gfGxBVMKtNP0")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.9/757.9 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 55.5 MB/s eta 0:00:00

# %%
dataset_location = "/content/tennis-ball-detection-6"  # Update this with the actual path
# !yolo task=detect mode=train model=yolov8x.pt data={dataset_location}/data.yaml epochs=25 imgsz=640
# Out:
# Ultralytics YOLOv8.2.19 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow
# Load the pretrained model (replace 'best.pt' with your model's path)
model = YOLO("/content/runs/detect/train2/weights/best.pt")

result = model.predict('/content/input_video.mp4',conf=0.1,save=True)
print(result)
for box in result[0].boxes:
  print(box)
# Out:
# Streaming output truncated to the last 5000 lines.
#         [173, 142, 104],
#         [173, 142, 104]]], dtype=uint8)
# orig_shape: (1080, 1920)
# path: '/content/input_video.mp4'
# probs: None
# save_dir: 'runs/detect/predict'
# speed: {'preprocess': 3.098726272583008, 'inference': 29.027700424194336, 'postprocess': 0.9729862213134766}, ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'tennis ball'}
# obb: None
# orig_img: array([[[ 20,  12,  27],
#         [ 19,  11,  26],
#         [ 12,   3,  21],
#         ...,
#         [ 17,   2,  45],
#         [ 17,   3,  42],
#         [ 17,   3,  42]],
#
#        [[ 20,  12,  27],
#         [ 18,  10,  25],
#         [ 12,   3,  21],
#         ...,
#         [ 25,  10,  53],
#         [ 26,  12,  51],
#         [ 25,  11,  50]],
#
#        [[ 21,  11,  31],
#         [ 21,  11,  31],
#         [ 19,   8,  31],
#         ...,
# ...
